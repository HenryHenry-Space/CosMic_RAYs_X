# %%
import robosuite as suite
from robosuite.controllers import load_controller_config
from robosuite.controllers.controller_factory import reset_controllers
from robosuite.utils import observables
from robosuite.utils.input_utils import *
from robosuite.robots import Bimanual
import time

options = {
    'env_name': 'EElab_test2',
    "robots": "UR5e"
}
controller_name = "JOINT_VELOCITY"
options["controller_configs"] = suite.load_controller_config(default_controller=controller_name)

action_dim = 6
num_test_steps = 6
test_value = 0.01
steps_per_action = 75
steps_per_rest = 75

env = suite.make(
    **options,
    gripper_types="Robotiq140Gripper",
    has_renderer=True,
    has_offscreen_renderer=False,
    ignore_done=True,
    use_camera_obs=False,
    horizon=(steps_per_action + steps_per_rest) * num_test_steps,
    control_freq=20,
)

# obs = {
#     'robot0_joint_pos_cos': None,
#     'robot0_joint_pos_sin': None,
#     'robot0_joint_vel': None,
#     'robot0_eef_pos': None,
#     'robot0_eef_quat': None,
#     'robot0_gripper_qpos': None,
#     'robot0_gripper_qvel': None,
#     'cubeA_pos': None,
#     'cubeA_quat': None,
#     'cubeB_pos': None,
#     'cubeB_quat': None,
#     'gripper_to_cubeA': None,
#     'gripper_to_cubeB': None,
#     'cubeA_to_cubeB': None,
# }

obs = env.reset()
o = list(obs['robot0_proprio-state']) + list(obs['object-state'])
print('length of o = ', len(o))
# env.viewer.set_camera(camera_id=0)

# To accommodate for multi-arm settings (e.g.: Baxter), we need to make sure to fill any extra action space
# Get total number of arms being controlled
# n = 0
gripper_dim = 1
# for robot in env.robots:
#     gripper_dim = robot.gripper["right"].dof if isinstance(robot, Bimanual) else robot.gripper.dof
#     print("gripper_dim=", gripper_dim)
    
    # n += int(robot.action_dim / (action_dim + gripper_dim))
    # print('n = ', n)

# Define neutral value
neutral = np.zeros(action_dim + gripper_dim)
# neutral = np.zeros(action_dim)
print("neutral=", neutral)
# Keep track of done variable to know when to break loop
count = 0
# Loop through controller space
while count < num_test_steps:
    action = neutral.copy()
    for i in range(steps_per_action):
        action[count] = test_value
        # print("action[count]=", action[count])
        # total_action = np.tile(action, 1)
        # print('total_action = ', total_action)
        obs, reward, done, _  = env.step(action)
        print('type of observer = ', obs)
        # print('reward = ', reward)
        env.render()
        time.sleep(5)
        # observables
    # for i in range(steps_per_rest):
    #     # total_action = np.tile(neutral, 1)
    #     env.step(action)
    #     env.render()
    count += 1

# Shut down this env before starting the next test
env.close()
# Out:
# Creating window glfw
# Creating window glfw
# length of o =  47
# neutral= [0. 0. 0. 0. 0. 0. 0.]
# type of observer =  OrderedDict([('robot0_joint_pos_cos', array([ 0.89683158, -0.16140847, -0.80088557, -0.63954503, -0.01469113,
#        -0.39136845])), ('robot0_joint_pos_sin', array([-0.44237214, -0.98688769,  0.59881742, -0.76875364, -0.99989208,
#        -0.92023407])), ('robot0_joint_vel', array([0., 0., 0., 0., 0., 0.])), ('robot0_eef_pos', array([ 0.34764921, -0.73747011,  0.90659066])), ('robot0_eef_quat', array([-0.99892562,  0.02777186,  0.03611352,  0.00849352])), ('robot0_gripper_qpos', array([ 0.012,  0.065,  0.065, -0.012,  0.065,  0.065])), ('robot0_gripper_qvel', array([0., 0., 0., 0., 0., 0.])), ('cubeA_pos', array([0.13788961, 0.02214959, 0.99715468])), ('cubeA_quat', array([0.        , 0.        , 0.5424092 , 0.84011443])), ('gripper_to_cubeA', array([-0.20975959,  0.7596197 ,  0.09056402])), ('robot0_proprio-state', array([ 0.89683158, -0.16140847, -0.80088557, -0.63954503, -0.01469113,
#        -0.39136845, -0.44237214, -0.98688769,  0.59881742, -0.76875364,
#        -0.99989208, -0.92023407,  0.        ,  0.        ,  0.        ,
#         0.        ,  0.        ,  0.        ,  0.34764921, -0.73747011,
#         0.90659066, -0.99892562,  0.02777186,  0.03611352,  0.00849352,
#         0.012     ,  0.065     ,  0.065     , -0.012     ,  0.065     ,
#         0.065     ,  0.        ,  0.        ,  0.        ,  0.        ,
#         0.        ,  0.        ])), ('object-state', array([ 0.13788961,  0.02214959,  0.99715468,  0.        ,  0.        ,
#         0.5424092 ,  0.84011443, -0.20975959,  0.7596197 ,  0.09056402]))])
# type of observer =  OrderedDict([('robot0_joint_pos_cos', array([ 0.89659768, -0.1656635 , -0.79388369, -0.6364707 , -0.02390637,
#        -0.39124523])), ('robot0_joint_pos_sin', array([-0.44284602, -0.98618234,  0.60806965, -0.77130088, -0.9997142 ,
#        -0.92028646])), ('robot0_joint_vel', array([-0.0534924 , -0.47697534, -0.70333887,  0.52876486, -0.58042418,
#         0.00821233])), ('robot0_eef_pos', array([ 0.34775278, -0.73649951,  0.90468545])), ('robot0_eef_quat', array([-0.99892019,  0.02752602,  0.03612077,  0.00980131])), ('robot0_gripper_qpos', array([ 0.0306439 ,  0.15228876,  0.04226277, -0.09372969,  0.13790193,
#        -0.01945111])), ('robot0_gripper_qvel', array([ 0.35320473,  3.95444457, -0.52167438, -4.08816093,  3.13876088,
#        -4.1428442 ])), ('cubeA_pos', array([0.13788961, 0.02214959, 0.99715468])), ('cubeA_quat', array([0.        , 0.        , 0.5424092 , 0.84011443])), ('gripper_to_cubeA', array([-0.20986316,  0.7586491 ,  0.09246923])), ('robot0_proprio-state', array([ 0.89659768, -0.1656635 , -0.79388369, -0.6364707 , -0.02390637,
#        -0.39124523, -0.44284602, -0.98618234,  0.60806965, -0.77130088,
#        -0.9997142 , -0.92028646, -0.0534924 , -0.47697534, -0.70333887,
#         0.52876486, -0.58042418,  0.00821233,  0.34775278, -0.73649951,
#         0.90468545, -0.99892019,  0.02752602,  0.03612077,  0.00980131,
#         0.0306439 ,  0.15228876,  0.04226277, -0.09372969,  0.13790193,
#        -0.01945111,  0.35320473,  3.95444457, -0.52167438, -4.08816093,
#         3.13876088, -4.1428442 ])), ('object-state', array([ 0.13788961,  0.02214959,  0.99715468,  0.        ,  0.        ,
#         0.5424092 ,  0.84011443, -0.20986316,  0.7586491 ,  0.09246923]))])
# type of observer =  OrderedDict([('robot0_joint_pos_cos', array([ 0.89713642, -0.17925031, -0.79038733, -0.63135654, -0.02294326,
#        -0.38806311])), ('robot0_joint_pos_sin', array([-0.4417536 , -0.9838035 ,  0.61260744, -0.77549269, -0.99973677,
#        -0.9216328 ])), ('robot0_joint_vel', array([ 0.24741956, -0.07519831,  0.20180827, -0.11918299,  0.32950688,
#         0.34428292])), ('robot0_eef_pos', array([ 0.35554791, -0.74805358,  0.9184278 ])), ('robot0_eef_quat', array([-0.9992087 ,  0.02817539,  0.02787253, -0.00335446])), ('robot0_gripper_qpos', array([ 0.12742955,  0.34317944, -0.05926798, -0.1429699 ,  0.21061668,
#        -0.07069524])), ('robot0_gripper_qvel', array([ 2.0354545 ,  1.55325526, -2.00197177,  0.97720869,  0.58429473,
#         0.95079808])), ('cubeA_pos', array([0.13788961, 0.02214959, 0.99715468])), ('cubeA_quat', array([0.        , 0.        , 0.5424092 , 0.84011443])), ('gripper_to_cubeA', array([-0.2176583 ,  0.77020316,  0.07872688])), ('robot0_proprio-state', array([ 0.89713642, -0.17925031, -0.79038733, -0.63135654, -0.02294326,
#        -0.38806311, -0.4417536 , -0.9838035 ,  0.61260744, -0.77549269,
#        -0.99973677, -0.9216328 ,  0.24741956, -0.07519831,  0.20180827,
#        -0.11918299,  0.32950688,  0.34428292,  0.35554791, -0.74805358,
#         0.9184278 , -0.9992087 ,  0.02817539,  0.02787253, -0.00335446,
#         0.12742955,  0.34317944, -0.05926798, -0.1429699 ,  0.21061668,
#        -0.07069524,  2.0354545 ,  1.55325526, -2.00197177,  0.97720869,
#         0.58429473,  0.95079808])), ('object-state', array([ 0.13788961,  0.02214959,  0.99715468,  0.        ,  0.        ,
#         0.5424092 ,  0.84011443, -0.2176583 ,  0.77020316,  0.07872688]))])
# type of observer =  OrderedDict([('robot0_joint_pos_cos', array([ 0.89677918, -0.18963632, -0.78326601, -0.62238578, -0.02981964,
#        -0.38984576])), ('robot0_joint_pos_sin', array([-0.44247836, -0.9818544 ,  0.6216867 , -0.78271063, -0.9995553 ,
#        -0.92088017])), ('robot0_joint_vel', array([ 0.21430653, -0.74014124,  0.2695142 , -0.01977092,  0.12194478,
#         0.26273566])), ('robot0_eef_pos', array([ 0.35872501, -0.75065455,  0.92169847])), ('robot0_eef_quat', array([-0.99919819,  0.02806848,  0.02815809, -0.00471891])), ('robot0_gripper_qpos', array([ 0.2023038 ,  0.54024338, -0.13852397, -0.23379526,  0.33154456,
#        -0.16401271])), ('robot0_gripper_qvel', array([ 3.66603138,  6.00169992, -3.71349854, -1.92958847,  5.48798175,
#        -2.10884475])), ('cubeA_pos', array([0.13788961, 0.02214959, 0.99715468])), ('cubeA_quat', array([0.        , 0.        , 0.5424092 , 0.84011443])), ('gripper_to_cubeA', array([-0.22083539,  0.77280414,  0.07545621])), ('robot0_proprio-state', array([ 8.96779181e-01, -1.89636320e-01, -7.83266010e-01, -6.22385783e-01,
#        -2.98196415e-02, -3.89845760e-01, -4.42478361e-01, -9.81854402e-01,
#         6.21686704e-01, -7.82710634e-01, -9.99555296e-01, -9.20880168e-01,
#         2.14306527e-01, -7.40141242e-01,  2.69514196e-01, -1.97709167e-02,
#         1.21944782e-01,  2.62735663e-01,  3.58725008e-01, -7.50654549e-01,
#         9.21698468e-01, -9.99198186e-01,  2.80684822e-02,  2.81580924e-02,
#        -4.71891054e-03,  2.02303799e-01,  5.40243380e-01, -1.38523971e-01,
#        -2.33795263e-01,  3.31544558e-01, -1.64012708e-01,  3.66603138e+00,
#         6.00169992e+00, -3.71349854e+00, -1.92958847e+00,  5.48798175e+00,
#        -2.10884475e+00])), ('object-state', array([ 0.13788961,  0.02214959,  0.99715468,  0.        ,  0.        ,
#         0.5424092 ,  0.84011443, -0.22083539,  0.77280414,  0.07545621]))])
# type of observer =  OrderedDict([('robot0_joint_pos_cos', array([ 0.89677918, -0.18963632, -0.78326601, -0.62238578, -0.02981964,
#        -0.38984576])), ('robot0_joint_pos_sin', array([-0.44247836, -0.9818544 ,  0.6216867 , -0.78271063, -0.9995553 ,
#        -0.92088017])), ('robot0_joint_vel', array([ 0.21430653, -0.74014124,  0.2695142 , -0.01977092,  0.12194478,
#         0.26273566])), ('robot0_eef_pos', array([ 0.35872501, -0.75065455,  0.92169847])), ('robot0_eef_quat', array([-0.99919819,  0.02806848,  0.02815809, -0.00471891])), ('robot0_gripper_qpos', array([ 0.2023038 ,  0.54024338, -0.13852397, -0.23379526,  0.33154456,
#        -0.16401271])), ('robot0_gripper_qvel', array([ 3.66603138,  6.00169992, -3.71349854, -1.92958847,  5.48798175,
#        -2.10884475])), ('cubeA_pos', array([0.13788961, 0.02214959, 0.99715468])), ('cubeA_quat', array([0.        , 0.        , 0.5424092 , 0.84011443])), ('gripper_to_cubeA', array([-0.22083539,  0.77280414,  0.07545621])), ('robot0_proprio-state', array([ 8.96779181e-01, -1.89636320e-01, -7.83266010e-01, -6.22385783e-01,
#        -2.98196415e-02, -3.89845760e-01, -4.42478361e-01, -9.81854402e-01,
#         6.21686704e-01, -7.82710634e-01, -9.99555296e-01, -9.20880168e-01,
#         2.14306527e-01, -7.40141242e-01,  2.69514196e-01, -1.97709167e-02,
#         1.21944782e-01,  2.62735663e-01,  3.58725008e-01, -7.50654549e-01,
#         9.21698468e-01, -9.99198186e-01,  2.80684822e-02,  2.81580924e-02,
#        -4.71891054e-03,  2.02303799e-01,  5.40243380e-01, -1.38523971e-01,
#        -2.33795263e-01,  3.31544558e-01, -1.64012708e-01,  3.66603138e+00,
#         6.00169992e+00, -3.71349854e+00, -1.92958847e+00,  5.48798175e+00,
#        -2.10884475e+00])), ('object-state', array([ 0.13788961,  0.02214959,  0.99715468,  0.        ,  0.        ,
#         0.5424092 ,  0.84011443, -0.22083539,  0.77280414,  0.07545621]))])
# type of observer =  OrderedDict([('robot0_joint_pos_cos', array([ 0.89457262, -0.18753873, -0.76878889, -0.61698881, -0.03959248,
#        -0.40141929])), ('robot0_joint_pos_sin', array([-0.44692261, -0.98225721,  0.63950265, -0.78697193, -0.99921591,
#        -0.9158944 ])), ('robot0_joint_vel', array([-0.22489458,  0.45039671, -0.72955983,  0.31277843, -0.2921121 ,
#        -0.43912748])), ('robot0_eef_pos', array([ 0.36313853, -0.75206095,  0.92952519])), ('robot0_eef_quat', array([-0.99942658,  0.02706993,  0.01737056, -0.01058287])), ('robot0_gripper_qpos', array([ 0.2420199 ,  0.71564544, -0.18958868, -0.08937458,  0.22707403,
#        -0.06639228])), ('robot0_gripper_qvel', array([-3.37564481, -4.07688214,  2.9818381 , 17.12531769, -4.04288738,
#        14.47191345])), ('cubeA_pos', array([0.13788961, 0.02214959, 0.99715468])), ('cubeA_quat', array([0.        , 0.        , 0.5424092 , 0.84011443])), ('gripper_to_cubeA', array([-0.22524891,  0.77421054,  0.06762948])), ('robot0_proprio-state', array([ 8.94572624e-01, -1.87538728e-01, -7.68788894e-01, -6.16988806e-01,
#        -3.95924757e-02, -4.01419293e-01, -4.46922611e-01, -9.82257209e-01,
#         6.39502648e-01, -7.86971927e-01, -9.99215911e-01, -9.15894400e-01,
#        -2.24894578e-01,  4.50396712e-01, -7.29559831e-01,  3.12778431e-01,
#        -2.92112104e-01, -4.39127476e-01,  3.63138525e-01, -7.52060954e-01,
#         9.29525191e-01, -9.99426578e-01,  2.70699262e-02,  1.73705626e-02,
#        -1.05828667e-02,  2.42019903e-01,  7.15645435e-01, -1.89588685e-01,
#        -8.93745798e-02,  2.27074027e-01, -6.63922798e-02, -3.37564481e+00,
#        -4.07688214e+00,  2.98183810e+00,  1.71253177e+01, -4.04288738e+00,
#         1.44719134e+01])), ('object-state', array([ 0.13788961,  0.02214959,  0.99715468,  0.        ,  0.        ,
#         0.5424092 ,  0.84011443, -0.22524891,  0.77421054,  0.06762948]))])
# type of observer =  OrderedDict([('robot0_joint_pos_cos', array([ 0.89491843, -0.18654782, -0.76833829, -0.61601799, -0.03576908,
#        -0.40438628])), ('robot0_joint_pos_sin', array([-0.44622976, -0.98244588,  0.64004396, -0.78773209, -0.99936008,
#        -0.91458829])), ('robot0_joint_vel', array([-0.18871595,  0.47398435, -0.563463  ,  0.34809402, -0.0763688 ,
#        -0.42604141])), ('robot0_eef_pos', array([ 0.36490291, -0.7530878 ,  0.93090452])), ('robot0_eef_quat', array([-0.99948409,  0.02531665,  0.01614731, -0.01139667])), ('robot0_gripper_qpos', array([ 0.25655861,  0.71787247, -0.20334164,  1.29457215,  0.49763643,
#         0.72841547])), ('robot0_gripper_qvel', array([ -2.90139845,  -4.58664249,   2.82209781, 106.799706  ,
#         -1.01272509,  72.99036651])), ('cubeA_pos', array([0.13788961, 0.02214959, 0.99715468])), ('cubeA_quat', array([0.        , 0.        , 0.5424092 , 0.84011443])), ('gripper_to_cubeA', array([-0.2270133 ,  0.77523739,  0.06625015])), ('robot0_proprio-state', array([ 8.94918433e-01, -1.86547824e-01, -7.68338289e-01, -6.16017987e-01,
#        -3.57690797e-02, -4.04386280e-01, -4.46229760e-01, -9.82445881e-01,
#         6.40043963e-01, -7.87732086e-01, -9.99360082e-01, -9.14588288e-01,
#        -1.88715953e-01,  4.73984352e-01, -5.63463004e-01,  3.48094018e-01,
#        -7.63687994e-02, -4.26041413e-01,  3.64902915e-01, -7.53087803e-01,
#         9.30904521e-01, -9.99484091e-01,  2.53166533e-02,  1.61473121e-02,
#        -1.13966718e-02,  2.56558613e-01,  7.17872465e-01, -2.03341642e-01,
#         1.29457215e+00,  4.97636433e-01,  7.28415474e-01, -2.90139845e+00,
#        -4.58664249e+00,  2.82209781e+00,  1.06799706e+02, -1.01272509e+00,
#         7.29903665e+01])), ('object-state', array([ 0.13788961,  0.02214959,  0.99715468,  0.        ,  0.        ,
#         0.5424092 ,  0.84011443, -0.2270133 ,  0.77523739,  0.06625015]))])
# type of observer =  OrderedDict([('robot0_joint_pos_cos', array([ 0.97216857, -0.18856885, -0.89283099, -0.49759917,  0.47876293,
#        -0.40192754])), ('robot0_joint_pos_sin', array([-0.23428248, -0.98205997,  0.45039185, -0.86740709, -0.87794422,
#        -0.91567147])), ('robot0_joint_vel', array([ 6.28784124,  0.62705023,  7.58252181,  4.81212149, 14.93014762,
#         0.30751441])), ('robot0_eef_pos', array([ 0.34258052, -0.63248749,  0.9106005 ])), ('robot0_eef_quat', array([-0.99256538, -0.02192172,  0.0228686 ,  0.11751783])), ('robot0_gripper_qpos', array([-12.36205862,   5.73409415,   1.73720256, -14.72247639,
#         -5.31188261,   1.97701891])), ('robot0_gripper_qvel', array([-1248.51072965,    72.76469917,   661.30701164,  -306.67769866,
#          -32.1029825 ,    12.57983493])), ('cubeA_pos', array([0.13788961, 0.02214959, 0.99715468])), ('cubeA_quat', array([0.        , 0.        , 0.5424092 , 0.84011443])), ('gripper_to_cubeA', array([-0.20469091,  0.65463707,  0.08655417])), ('robot0_proprio-state', array([ 9.72168566e-01, -1.88568853e-01, -8.92830992e-01, -4.97599168e-01,
#         4.78762931e-01, -4.01927544e-01, -2.34282479e-01, -9.82059972e-01,
#         4.50391851e-01, -8.67407095e-01, -8.77944221e-01, -9.15671474e-01,
#         6.28784124e+00,  6.27050232e-01,  7.58252181e+00,  4.81212149e+00,
#         1.49301476e+01,  3.07514408e-01,  3.42580523e-01, -6.32487487e-01,
#         9.10600505e-01, -9.92565376e-01, -2.19217242e-02,  2.28685994e-02,
#         1.17517829e-01, -1.23620586e+01,  5.73409415e+00,  1.73720256e+00,
#        -1.47224764e+01, -5.31188261e+00,  1.97701891e+00, -1.24851073e+03,
#         7.27646992e+01,  6.61307012e+02, -3.06677699e+02, -3.21029825e+01,
#         1.25798349e+01])), ('object-state', array([ 0.13788961,  0.02214959,  0.99715468,  0.        ,  0.        ,
#         0.5424092 ,  0.84011443, -0.20469091,  0.65463707,  0.08655417]))])
# type of observer =  OrderedDict([('robot0_joint_pos_cos', array([ 0.99064487, -0.2983885 , -0.8723331 , -0.46330238,  0.73863729,
#        -0.42335468])), ('robot0_joint_pos_sin', array([ 0.1364652 , -0.9544445 ,  0.48891202, -0.88620026,  0.67410308,
#        -0.90596402])), ('robot0_joint_vel', array([ 8.8910484 , -3.1192936 , -3.19918255,  0.30525166, 47.81224818,
#        -0.27435173])), ('robot0_eef_pos', array([ 0.26147693, -0.29001873,  1.09133555])), ('robot0_eef_quat', array([-0.77353208, -0.02758793,  0.00503741,  0.63313636])), ('robot0_gripper_qpos', array([ 280.11485326, -182.22010975,   50.65676611,   12.53859314,
#         -30.17754914,    4.52239201])), ('robot0_gripper_qvel', array([14306.85465421, -9632.11340312,  2548.35735657,  1164.03343325,
#        -1342.79474088,   163.71795523])), ('cubeA_pos', array([0.13788961, 0.02214959, 0.99715468])), ('cubeA_quat', array([0.        , 0.        , 0.5424092 , 0.84011443])), ('gripper_to_cubeA', array([-0.12358732,  0.31216832, -0.09418087])), ('robot0_proprio-state', array([ 9.90644865e-01, -2.98388500e-01, -8.72333102e-01, -4.63302377e-01,
#         7.38637287e-01, -4.23354682e-01,  1.36465202e-01, -9.54444500e-01,
#         4.88912015e-01, -8.86200264e-01,  6.74103077e-01, -9.05964024e-01,
#         8.89104840e+00, -3.11929360e+00, -3.19918255e+00,  3.05251664e-01,
#         4.78122482e+01, -2.74351730e-01,  2.61476934e-01, -2.90018732e-01,
#         1.09133555e+00, -7.73532079e-01, -2.75879348e-02,  5.03740795e-03,
#         6.33136363e-01,  2.80114853e+02, -1.82220110e+02,  5.06567661e+01,
#         1.25385931e+01, -3.01775491e+01,  4.52239201e+00,  1.43068547e+04,
#        -9.63211340e+03,  2.54835736e+03,  1.16403343e+03, -1.34279474e+03,
#         1.63717955e+02])), ('object-state', array([ 0.13788961,  0.02214959,  0.99715468,  0.        ,  0.        ,
#         0.5424092 ,  0.84011443, -0.12358732,  0.31216832, -0.09418087]))])
# type of observer =  OrderedDict([('robot0_joint_pos_cos', array([ 0.99064487, -0.2983885 , -0.8723331 , -0.46330238,  0.73863729,
#        -0.42335468])), ('robot0_joint_pos_sin', array([ 0.1364652 , -0.9544445 ,  0.48891202, -0.88620026,  0.67410308,
#        -0.90596402])), ('robot0_joint_vel', array([ 8.8910484 , -3.1192936 , -3.19918255,  0.30525166, 47.81224818,
#        -0.27435173])), ('robot0_eef_pos', array([ 0.26147693, -0.29001873,  1.09133555])), ('robot0_eef_quat', array([-0.77353208, -0.02758793,  0.00503741,  0.63313636])), ('robot0_gripper_qpos', array([ 280.11485326, -182.22010975,   50.65676611,   12.53859314,
#         -30.17754914,    4.52239201])), ('robot0_gripper_qvel', array([14306.85465421, -9632.11340312,  2548.35735657,  1164.03343325,
#        -1342.79474088,   163.71795523])), ('cubeA_pos', array([0.13788961, 0.02214959, 0.99715468])), ('cubeA_quat', array([0.        , 0.        , 0.5424092 , 0.84011443])), ('gripper_to_cubeA', array([-0.12358732,  0.31216832, -0.09418087])), ('robot0_proprio-state', array([ 9.90644865e-01, -2.98388500e-01, -8.72333102e-01, -4.63302377e-01,
#         7.38637287e-01, -4.23354682e-01,  1.36465202e-01, -9.54444500e-01,
#         4.88912015e-01, -8.86200264e-01,  6.74103077e-01, -9.05964024e-01,
#         8.89104840e+00, -3.11929360e+00, -3.19918255e+00,  3.05251664e-01,
#         4.78122482e+01, -2.74351730e-01,  2.61476934e-01, -2.90018732e-01,
#         1.09133555e+00, -7.73532079e-01, -2.75879348e-02,  5.03740795e-03,
#         6.33136363e-01,  2.80114853e+02, -1.82220110e+02,  5.06567661e+01,
#         1.25385931e+01, -3.01775491e+01,  4.52239201e+00,  1.43068547e+04,
#        -9.63211340e+03,  2.54835736e+03,  1.16403343e+03, -1.34279474e+03,
#         1.63717955e+02])), ('object-state', array([ 0.13788961,  0.02214959,  0.99715468,  0.        ,  0.        ,
#         0.5424092 ,  0.84011443, -0.12358732,  0.31216832, -0.09418087]))])
# ---------------------------------------------------------------------------
# MujocoException                           Traceback (most recent call last)
# /tmp/ipykernel_16453/2872256958.py in <module>
#      78         # total_action = np.tile(action, 1)
#      79         # print('total_action = ', total_action)
# ---> 80         obs, reward, done, _  = env.step(action)
#      81         print('type of observer = ', obs)
#      82         # print('reward = ', reward)
#
# ~/Cosmic_rays_X/X_Robot/robosuite/robosuite/environments/base.py in step(self, action)
#     405             self.sim.forward()
#     406             self._pre_action(action, policy_step)
# --> 407             self.sim.step()
#     408             self._update_observables()
#     409             policy_step = False
#
# mjsim.pyx in mujoco_py.cymj.MjSim.step()
#
# cymj.pyx in mujoco_py.cymj.wrap_mujoco_warning.__exit__()
#
# cymj.pyx in mujoco_py.cymj.c_warning_callback()
#
# ~/anaconda3/envs/cosmic_rays_x_py38_env/lib/python3.8/site-packages/mujoco_py/builder.py in user_warning_raise_exception(warn_bytes)
#     362     if 'Unknown warning type' in warn:
#     363         raise MujocoException(warn + 'Check for NaN in simulation.')
# --> 364     raise MujocoException('Got MuJoCo Warning: {}'.format(warn))
#     365
#     366
#
# MujocoException: Got MuJoCo Warning: Nan, Inf or huge value in QACC at DOF 6. The simulation is unstable. Time = 0.4000.

# %%
a = np.array([0, 1, 2])
np_a = np.tile(a, 1)
print('np_a = ', np_a)
# Out:
# np_a =  [0 1 2]

# %%
import robosuite as suite
from robosuite.controllers import load_controller_config
from robosuite.controllers.controller_factory import reset_controllers
from robosuite.utils import observables
from robosuite.utils.input_utils import *
from robosuite.robots import Bimanual
import time
import imageio
import numpy as np
import robosuite.utils.macros as macros
macros.IMAGE_CONVENTION = "opencv"

options = {
    'env_name': 'EElab_test2',
    "robots": "UR5e"
}
controller_name = "JOINT_VELOCITY"
options["controller_configs"] = suite.load_controller_config(default_controller=controller_name)

action_dim = 6
num_test_steps = 6
test_value = 0.3
steps_per_action = 75
steps_per_rest = 75


env = suite.make(
    **options,
    has_renderer=False,
    has_offscreen_renderer=True,
    ignore_done=True,
    use_camera_obs=True,
    render_gpu_device_id = -1,
    control_freq=20,
    camera_names='Labviewer',
    camera_heights=512,
    camera_widths=512,
)
frame = []
writer = imageio.get_writer(
"/home/xhnfly/Cosmic_rays_X/X_Robot/robosuite/robosuite/demos/video/test.mp4", fps=100)

obs = env.reset()

gripper_dim = 0

# Define neutral value
neutral = np.zeros(action_dim + gripper_dim)
print("neutral=", neutral)
# Keep track of done variable to know when to break loop
count = 0
# Loop through controller space

action = neutral.copy()

for i in range(steps_per_action):
    action[count] = test_value
    # print("action[count]=", action[count])
    # total_action = np.tile(action, 1)
    # print('total_action = ', total_action)
    obs, reward, done, _  = env.step(action)
    frame = obs["Labviewer_image"]
    writer.append_data(frame)


writer.close()
# Out:
# neutral= [0. 0. 0. 0. 0. 0. 0.]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_15349/3470605745.py in <module>
#      59     # total_action = np.tile(action, 1)
#      60     # print('total_action = ', total_action)
# ---> 61     obs, reward, done, _  = env.step(action)
#      62     frame = obs["Labviewer_image"]
#      63     writer.append_data(frame)
#
# ~/Cosmic_rays_X/X_Robot/robosuite/robosuite/environments/base.py in step(self, action)
#     404         for i in range(int(self.control_timestep / self.model_timestep)):
#     405             self.sim.forward()
# --> 406             self._pre_action(action, policy_step)
#     407             self.sim.step()
#     408             self._update_observables()
#
# ~/Cosmic_rays_X/X_Robot/robosuite/robosuite/environments/robot_env.py in _pre_action(self, action, policy_step)
#     573         """
#     574         # Verify that the action is the correct dimension
# --> 575         assert len(action) == self.action_dim, "environment got invalid action dimension -- expected {}, got {}".format(
#     576             self.action_dim, len(action)
#     577         )
#
# AssertionError: environment got invalid action dimension -- expected 6, got 7

# %%
o2 =  [ 0.99997906  0.998376   -0.00647075  0.05696805  0.08787639  
0.08591351
  2.59731069 -0.0294459   0.12198118 -0.08100713  0.        ]

# %%
import numpy as np

a = np.array([0, 1, 2, 3])
print('a = ', a)
print('a[:2] = ', a[:2])
print('a[2:] = ', a[2:])
# Out:
# a =  [0 1 2 3]
# a[:2] =  [0 1]
# a[2:] =  [2 3]

# %%
observer =  OrderedDict([
    ('robot0_joint_pos_cos', array([ 0.89937101, -0.1695662 , -0.78957319, -0.64421908, -0.0019053 , -0.42111994])), 
    ('robot0_joint_pos_sin', array([-0.43718621, -0.9855188 ,  0.6136564 , -0.76484101, -0.99999818, -0.90700496])), 
    ('robot0_joint_vel', array([ 0.14439801, -0.03286442, -0.02295799,  0.01734262, -0.05538252, 0.03374301])), 
    ('robot0_eef_pos', array([ 0.36243414, -0.73833533,  0.91635013])), 
    ('robot0_eef_quat', array([-0.99976124,  0.00898486,  0.01835605,  0.00773266])), 
    ('robot0_gripper_qpos', array([ 0.09342021,  0.09180312, -0.01587478, -0.03282569,  0.11682881, 0.0425271 ])), 
    ('robot0_gripper_qvel', array([ 0.0330767 , -0.27930619,  0.00542595, -0.18098557,  0.62173095, -0.19943657])), 
    ('cubeA_pos', array([-0.09763264, -0.03187963,  0.93845694])), 
    ('cubeA_quat', array([ 0.        ,  0.        ,  0.04443746, -0.99901217])), 
    ('gripper_to_cubeA', array([-0.46006678,  0.7064557 ,  0.0221068 ])), 
    ('robot0_proprio-state', array([ 0.89937101, -0.1695662 , -0.78957319, -0.64421908, -0.0019053 ,
                                    -0.42111994, -0.43718621, -0.9855188 ,  0.6136564 , -0.76484101,
                                    -0.99999818, -0.90700496,  0.14439801, -0.03286442, -0.02295799,
                                    0.01734262, -0.05538252,  0.03374301,  0.36243414, -0.73833533,
                                    0.91635013, -0.99976124,  0.00898486,  0.01835605,  0.00773266,
                                    0.09342021,  0.09180312, -0.01587478, -0.03282569,  0.11682881,
                                    0.0425271 ,  0.0330767 , -0.27930619,  0.00542595, -0.18098557,
                                    0.62173095, -0.19943657])), 
    ('object-state', array([-0.09763264, -0.03187963,  0.93845694,  0.        ,  0.        ,
        0.04443746, -0.99901217, -0.46006678,  0.7064557 ,  0.0221068 ]))
        ])
